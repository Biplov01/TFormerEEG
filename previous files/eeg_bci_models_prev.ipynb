# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/combined_eeg_features.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Bidirectional, LSTM, GRU, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Train-Test Split with Stratification
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, shuffle=True, random_state=42
)

# Convert labels to categorical for evaluation,
# but pass integer labels during training (using np.argmax)
num_classes = len(np.unique(y))
y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

# ------------------------
# Build the BiLSTM-BiGRU Model
# ------------------------
def build_model(input_shape, num_classes):
    inputs = Input(shape=(input_shape,))
    
    # Wrap tf.expand_dims inside Lambda to expand dimensions
    x = Lambda(lambda t: tf.expand_dims(t, axis=1))(inputs)
    
    # Bi-LSTM layer with L2 regularization and return sequences
    x = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l2(0.01)))(x)
    
    # Bi-GRU layer with return sequences
    x = Bidirectional(GRU(128, return_sequences=False, kernel_regularizer=l2(0.01)))(x)
    
    # Dropout layer for regularization
    x = Dropout(0.2)(x)
    
    # Final dense layer with softmax activation for classification
    outputs = Dense(num_classes, activation="softmax")(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

# Build the model
model = build_model(X_train.shape[1], num_classes)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# ------------------------
# Train the Model
# ------------------------
history = model.fit(X_train, y_train,
                    validation_split=0.2,
                    epochs=250,
                    batch_size=128,
                    callbacks=[early_stopping],
                    verbose=1)

# ------------------------
# Evaluate the Model
# ------------------------
y_train_pred = np.argmax(model.predict(X_train), axis=1)
y_test_pred = np.argmax(model.predict(X_test), axis=1)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Testing Accuracy: {test_accuracy:.4f}")

from sklearn.metrics import classification_report

# Print classification report for the test set
print("\nClassification Report (Test Set):")
print(classification_report(y_test, y_test_pred, digits=4))

# ------------------------
# Plot Confusion Matrix
# ------------------------
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(6,5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap="Blues",
            xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# ------------------------
# Plot Training History
# ------------------------
plt.figure(figsize=(12,5))

# Plot Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()

# Plot Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()

plt.show()
# Out:
# Epoch 1/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.4979 - loss: 24.5346 - val_accuracy: 0.7541 - val_loss: 22.3483
# Epoch 2/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7848 - loss: 21.6941 - val_accuracy: 0.8049 - val_loss: 19.8538
# Epoch 3/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8061 - loss: 19.2715 - val_accuracy: 0.8197 - val_loss: 17.6854
# Epoch 4/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8437 - loss: 17.1460 - val_accuracy: 0.8344 - val_loss: 15.7587
# Epoch 5/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8737 - loss: 15.2628 - val_accuracy: 0.8459 - val_loss: 14.0640
# Epoch 6/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9062 - loss: 13.5848 - val_accuracy: 0.8459 - val_loss: 12.5864
# Epoch 7/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9236 - loss: 12.1359 - val_accuracy: 0.8574 - val_loss: 11.2793
# Epoch 8/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9302 - loss: 10.8586 - val_accuracy: 0.8525 - val_loss: 10.1223
# Epoch 9/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9267 - loss: 9.7315 - val_accuracy: 0.8607 - val_loss: 9.0897
# Epoch 10/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9546 - loss: 8.7116 - val_accuracy: 0.8689 - val_loss: 8.1830
# Epoch 11/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9628 - loss: 7.8091 - val_accuracy: 0.8738 - val_loss: 7.3725
# Epoch 12/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9650 - loss: 7.0332 - val_accuracy: 0.8754 - val_loss: 6.6656
# Epoch 13/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9662 - loss: 6.3479 - val_accuracy: 0.8803 - val_loss: 6.0461
# Epoch 14/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9708 - loss: 5.7357 - val_accuracy: 0.8738 - val_loss: 5.4918
# Epoch 15/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9808 - loss: 5.1871 - val_accuracy: 0.8770 - val_loss: 5.0180
# Epoch 16/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9807 - loss: 4.7227 - val_accuracy: 0.8738 - val_loss: 4.5864
# Epoch 17/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9820 - loss: 4.2929 - val_accuracy: 0.8770 - val_loss: 4.1929
# Epoch 18/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9855 - loss: 3.9031 - val_accuracy: 0.8787 - val_loss: 3.8460
# Epoch 19/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9837 - loss: 3.5634 - val_accuracy: 0.8820 - val_loss: 3.5298
# Epoch 20/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 3.2559 - val_accuracy: 0.8869 - val_loss: 3.2483
# Epoch 21/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9895 - loss: 2.9744 - val_accuracy: 0.8918 - val_loss: 2.9949
# Epoch 22/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9896 - loss: 2.7272 - val_accuracy: 0.8902 - val_loss: 2.7667
# Epoch 23/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9942 - loss: 2.5027 - val_accuracy: 0.8951 - val_loss: 2.5667
# Epoch 24/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9909 - loss: 2.3059 - val_accuracy: 0.8934 - val_loss: 2.3772
# Epoch 25/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9927 - loss: 2.1245 - val_accuracy: 0.8902 - val_loss: 2.2182
# Epoch 26/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9935 - loss: 1.9606 - val_accuracy: 0.8918 - val_loss: 2.0680
# Epoch 27/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9861 - loss: 1.8233 - val_accuracy: 0.8934 - val_loss: 1.9390
# Epoch 28/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9944 - loss: 1.6894 - val_accuracy: 0.8902 - val_loss: 1.8172
# Epoch 29/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9952 - loss: 1.5628 - val_accuracy: 0.8918 - val_loss: 1.6921
# Epoch 30/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9952 - loss: 1.4453 - val_accuracy: 0.8951 - val_loss: 1.5886
# Epoch 31/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9959 - loss: 1.3441 - val_accuracy: 0.8967 - val_loss: 1.4927
# Epoch 32/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9959 - loss: 1.2509 - val_accuracy: 0.9000 - val_loss: 1.4062
# Epoch 33/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9962 - loss: 1.1672 - val_accuracy: 0.8951 - val_loss: 1.3291
# Epoch 34/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9960 - loss: 1.0887 - val_accuracy: 0.8918 - val_loss: 1.2605
# Epoch 35/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9963 - loss: 1.0169 - val_accuracy: 0.8902 - val_loss: 1.2026
# Epoch 36/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9972 - loss: 0.9537 - val_accuracy: 0.8885 - val_loss: 1.1352
# Epoch 37/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9951 - loss: 0.8936 - val_accuracy: 0.8885 - val_loss: 1.0885
# Epoch 38/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9965 - loss: 0.8347 - val_accuracy: 0.8984 - val_loss: 1.0217
# Epoch 39/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9956 - loss: 0.7848 - val_accuracy: 0.8934 - val_loss: 0.9812
# Epoch 40/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9971 - loss: 0.7356 - val_accuracy: 0.8967 - val_loss: 0.9330
# Epoch 41/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.6927 - val_accuracy: 0.8918 - val_loss: 0.8916
# Epoch 42/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9970 - loss: 0.6505 - val_accuracy: 0.8967 - val_loss: 0.8540
# Epoch 43/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9959 - loss: 0.6119 - val_accuracy: 0.8984 - val_loss: 0.8171
# Epoch 44/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9978 - loss: 0.5724 - val_accuracy: 0.8967 - val_loss: 0.7899
# Epoch 45/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9989 - loss: 0.5421 - val_accuracy: 0.8934 - val_loss: 0.7582
# Epoch 46/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9968 - loss: 0.5120 - val_accuracy: 0.9000 - val_loss: 0.7290
# Epoch 47/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9981 - loss: 0.4817 - val_accuracy: 0.9000 - val_loss: 0.6952
# Epoch 48/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9979 - loss: 0.4548 - val_accuracy: 0.8902 - val_loss: 0.6792
# Epoch 49/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9982 - loss: 0.4343 - val_accuracy: 0.8951 - val_loss: 0.6576
# Epoch 50/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9994 - loss: 0.4098 - val_accuracy: 0.9016 - val_loss: 0.6254
# Epoch 51/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9983 - loss: 0.3901 - val_accuracy: 0.8934 - val_loss: 0.6181
# Epoch 52/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9990 - loss: 0.3687 - val_accuracy: 0.9000 - val_loss: 0.5952
# Epoch 53/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9991 - loss: 0.3533 - val_accuracy: 0.8918 - val_loss: 0.5931
# Epoch 54/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9986 - loss: 0.3372 - val_accuracy: 0.8869 - val_loss: 0.5669
# Epoch 55/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9959 - loss: 0.3277 - val_accuracy: 0.8951 - val_loss: 0.5641
# Epoch 56/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9982 - loss: 0.3132 - val_accuracy: 0.8885 - val_loss: 0.5622
# Epoch 57/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9977 - loss: 0.3007 - val_accuracy: 0.8852 - val_loss: 0.5427
# Epoch 58/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9985 - loss: 0.2867 - val_accuracy: 0.8934 - val_loss: 0.5374
# Epoch 59/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9977 - loss: 0.2838 - val_accuracy: 0.8885 - val_loss: 0.5289
# Epoch 60/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9984 - loss: 0.1614 - val_accuracy: 0.8902 - val_loss: 0.4328
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training Accuracy: 0.9806
# Testing Accuracy: 0.9226
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#          0.0     0.9288    0.9580    0.9432       381
#          1.0     0.8923    0.9016    0.8969       193
#          2.0     0.9425    0.8723    0.9061       188
#
#     accuracy                         0.9226       762
#    macro avg     0.9212    0.9106    0.9154       762
# weighted avg     0.9229    0.9226    0.9223       762

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Bidirectional, LSTM, GRU, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Train-Test Split with Stratification
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, shuffle=True, random_state=42
)

# Convert labels to categorical for evaluation,
# but pass integer labels during training (using np.argmax)
num_classes = len(np.unique(y))
y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

# ------------------------
# Build the BiLSTM-BiGRU Model
# ------------------------
def build_model(input_shape, num_classes):
    inputs = Input(shape=(input_shape,))
    
    # Wrap tf.expand_dims inside Lambda to expand dimensions
    x = Lambda(lambda t: tf.expand_dims(t, axis=1))(inputs)
    
    # Bi-LSTM layer with L2 regularization and return sequences
    x = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l2(0.01)))(x)
    
    # Bi-GRU layer with return sequences
    x = Bidirectional(GRU(128, return_sequences=False, kernel_regularizer=l2(0.01)))(x)
    
    # Dropout layer for regularization
    x = Dropout(0.2)(x)
    
    # Final dense layer with softmax activation for classification
    outputs = Dense(num_classes, activation="softmax")(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

# Build the model
model = build_model(X_train.shape[1], num_classes)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# ------------------------
# Train the Model
# ------------------------
history = model.fit(X_train, y_train,
                    validation_split=0.2,
                    epochs=250,
                    batch_size=128,
                    callbacks=[early_stopping],
                    verbose=1)

# ------------------------
# Evaluate the Model
# ------------------------
y_train_pred = np.argmax(model.predict(X_train), axis=1)
y_test_pred = np.argmax(model.predict(X_test), axis=1)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Testing Accuracy: {test_accuracy:.4f}")

from sklearn.metrics import classification_report

# Print classification report for the test set
print("\nClassification Report (Test Set):")
print(classification_report(y_test, y_test_pred, digits=4))

# ------------------------
# Plot Confusion Matrix
# ------------------------
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(6,5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap="Blues",
            xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# ------------------------
# Plot Training History
# ------------------------
plt.figure(figsize=(12,5))

# Plot Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()

# Plot Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()

plt.show()
# Out:
# Epoch 1/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.4896 - loss: 24.5568 - val_accuracy: 0.7295 - val_loss: 22.3759
# Epoch 2/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7614 - loss: 21.7318 - val_accuracy: 0.7803 - val_loss: 19.9038
# Epoch 3/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8101 - loss: 19.3108 - val_accuracy: 0.8098 - val_loss: 17.7297
# Epoch 4/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8684 - loss: 17.1688 - val_accuracy: 0.8311 - val_loss: 15.8206
# Epoch 5/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8881 - loss: 15.3127 - val_accuracy: 0.8344 - val_loss: 14.1350
# Epoch 6/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9106 - loss: 13.6585 - val_accuracy: 0.8377 - val_loss: 12.6662
# Epoch 7/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9122 - loss: 12.2155 - val_accuracy: 0.8492 - val_loss: 11.3615
# Epoch 8/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9296 - loss: 10.9307 - val_accuracy: 0.8623 - val_loss: 10.1946
# Epoch 9/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9392 - loss: 9.7937 - val_accuracy: 0.8590 - val_loss: 9.1705
# Epoch 10/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9436 - loss: 8.7928 - val_accuracy: 0.8623 - val_loss: 8.2743
# Epoch 11/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9533 - loss: 7.9107 - val_accuracy: 0.8607 - val_loss: 7.4877
# Epoch 12/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9641 - loss: 7.1293 - val_accuracy: 0.8639 - val_loss: 6.7731
# Epoch 13/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9654 - loss: 6.4329 - val_accuracy: 0.8721 - val_loss: 6.1389
# Epoch 14/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9673 - loss: 5.8063 - val_accuracy: 0.8738 - val_loss: 5.5789
# Epoch 15/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9744 - loss: 5.2659 - val_accuracy: 0.8803 - val_loss: 5.0801
# Epoch 16/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9772 - loss: 4.7680 - val_accuracy: 0.8803 - val_loss: 4.6329
# Epoch 17/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9831 - loss: 4.3344 - val_accuracy: 0.8836 - val_loss: 4.2355
# Epoch 18/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9851 - loss: 3.9468 - val_accuracy: 0.8852 - val_loss: 3.8834
# Epoch 19/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 3.5951 - val_accuracy: 0.8836 - val_loss: 3.5656
# Epoch 20/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9861 - loss: 3.2922 - val_accuracy: 0.8852 - val_loss: 3.2884
# Epoch 21/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9839 - loss: 3.0200 - val_accuracy: 0.8852 - val_loss: 3.0304
# Epoch 22/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9894 - loss: 2.7626 - val_accuracy: 0.8852 - val_loss: 2.8060
# Epoch 23/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9842 - loss: 2.5496 - val_accuracy: 0.8885 - val_loss: 2.6055
# Epoch 24/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9896 - loss: 2.3467 - val_accuracy: 0.8869 - val_loss: 2.4198
# Epoch 25/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9927 - loss: 2.1539 - val_accuracy: 0.8869 - val_loss: 2.2504
# Epoch 26/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9929 - loss: 1.9888 - val_accuracy: 0.8803 - val_loss: 2.1014
# Epoch 27/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9931 - loss: 1.8481 - val_accuracy: 0.8869 - val_loss: 1.9668
# Epoch 28/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9948 - loss: 1.7153 - val_accuracy: 0.8951 - val_loss: 1.8379
# Epoch 29/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9942 - loss: 1.5876 - val_accuracy: 0.8918 - val_loss: 1.7252
# Epoch 30/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9944 - loss: 1.4713 - val_accuracy: 0.8951 - val_loss: 1.6139
# Epoch 31/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9981 - loss: 1.3627 - val_accuracy: 0.8934 - val_loss: 1.5205
# Epoch 32/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9955 - loss: 1.2715 - val_accuracy: 0.8934 - val_loss: 1.4431
# Epoch 33/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9978 - loss: 1.1809 - val_accuracy: 0.8885 - val_loss: 1.3564
# Epoch 34/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9974 - loss: 1.0999 - val_accuracy: 0.8902 - val_loss: 1.2828
# Epoch 35/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9972 - loss: 1.0292 - val_accuracy: 0.8918 - val_loss: 1.2074
# Epoch 36/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9974 - loss: 0.9599 - val_accuracy: 0.8869 - val_loss: 1.1558
# Epoch 37/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.8977 - val_accuracy: 0.8951 - val_loss: 1.0888
# Epoch 38/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9971 - loss: 0.8412 - val_accuracy: 0.8951 - val_loss: 1.0315
# Epoch 39/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9954 - loss: 0.7939 - val_accuracy: 0.8902 - val_loss: 0.9862
# Epoch 40/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9926 - loss: 0.7500 - val_accuracy: 0.8934 - val_loss: 0.9493
# Epoch 41/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9970 - loss: 0.7043 - val_accuracy: 0.8967 - val_loss: 0.9056
# Epoch 42/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9883 - loss: 0.6782 - val_accuracy: 0.8918 - val_loss: 0.8875
# Epoch 43/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9929 - loss: 0.6343 - val_accuracy: 0.9033 - val_loss: 0.8292
# Epoch 44/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9985 - loss: 0.5890 - val_accuracy: 0.8984 - val_loss: 0.8007
# Epoch 45/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9959 - loss: 0.5523 - val_accuracy: 0.8967 - val_loss: 0.7662
# Epoch 46/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9975 - loss: 0.5273 - val_accuracy: 0.8852 - val_loss: 0.7652
# Epoch 47/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9975 - loss: 0.5035 - val_accuracy: 0.8967 - val_loss: 0.7197
# Epoch 48/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9983 - loss: 0.4693 - val_accuracy: 0.8934 - val_loss: 0.6938
# Epoch 49/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9983 - loss: 0.4447 - val_accuracy: 0.8902 - val_loss: 0.6705
# Epoch 50/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9980 - loss: 0.4224 - val_accuracy: 0.8984 - val_loss: 0.6438
# Epoch 51/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9971 - loss: 0.4103 - val_accuracy: 0.8803 - val_loss: 0.6761
# Epoch 52/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9932 - loss: 0.3990 - val_accuracy: 0.8967 - val_loss: 0.6209
# Epoch 53/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9974 - loss: 0.3690 - val_accuracy: 0.8918 - val_loss: 0.6023
# Epoch 54/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9977 - loss: 0.3518 - val_accuracy: 0.8852 - val_loss: 0.6052
# Epoch 55/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9988 - loss: 0.3318 - val_accuracy: 0.9000 - val_loss: 0.5741
# Epoch 56/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9989 - loss: 0.1565 - val_accuracy: 0.9000 - val_loss: 0.4068
# Epoch 94/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9994 - loss: 0.1541 - val_accuracy: 0.9049 - val_loss: 0.4157
# Epoch 95/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9999 - loss: 0.1510 - val_accuracy: 0.8934 - val_loss: 0.4133
# Epoch 96/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9997 - loss: 0.1465 - val_accuracy: 0.8918 - val_loss: 0.4051
# Epoch 97/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9999 - loss: 0.1427 - val_accuracy: 0.8951 - val_loss: 0.4095
# Epoch 98/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9998 - loss: 0.1432 - val_accuracy: 0.8885 - val_loss: 0.4137
# Epoch 99/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9983 - loss: 0.1444 - val_accuracy: 0.8885 - val_loss: 0.4202
# Epoch 100/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1398 - val_accuracy: 0.8967 - val_loss: 0.4002
# Epoch 101/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1378 - val_accuracy: 0.8918 - val_loss: 0.4060
# Epoch 102/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9999 - loss: 0.1354 - val_accuracy: 0.8902 - val_loss: 0.4062
# Epoch 103/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9999 - loss: 0.1338 - val_accuracy: 0.9016 - val_loss: 0.3988
# Epoch 104/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1350 - val_accuracy: 0.9033 - val_loss: 0.3938
# Epoch 105/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1348 - val_accuracy: 0.8885 - val_loss: 0.4162
# Epoch 106/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9999 - loss: 0.1335 - val_accuracy: 0.8902 - val_loss: 0.4004
# Epoch 107/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9999 - loss: 0.1343 - val_accuracy: 0.8934 - val_loss: 0.4065
# Epoch 108/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1345 - val_accuracy: 0.8951 - val_loss: 0.4111
# Epoch 109/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1311 - val_accuracy: 0.9000 - val_loss: 0.4079
# Epoch 110/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9995 - loss: 0.1334 - val_accuracy: 0.9016 - val_loss: 0.3933
# Epoch 111/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9999 - loss: 0.1304 - val_accuracy: 0.8951 - val_loss: 0.4126
# Epoch 112/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9994 - loss: 0.1350 - val_accuracy: 0.8885 - val_loss: 0.4136
# Epoch 113/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9995 - loss: 0.1333 - val_accuracy: 0.8984 - val_loss: 0.4080
# Epoch 114/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9977 - loss: 0.1351 - val_accuracy: 0.9016 - val_loss: 0.4150
# Epoch 115/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9997 - loss: 0.1333 - val_accuracy: 0.8885 - val_loss: 0.4225
# Epoch 116/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1306 - val_accuracy: 0.8967 - val_loss: 0.4043
# Epoch 117/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9994 - loss: 0.1303 - val_accuracy: 0.9016 - val_loss: 0.4103
# Epoch 118/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9999 - loss: 0.1288 - val_accuracy: 0.9000 - val_loss: 0.4007
# Epoch 119/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1259 - val_accuracy: 0.8869 - val_loss: 0.4088
# Epoch 120/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1239 - val_accuracy: 0.8951 - val_loss: 0.3960
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training Accuracy: 0.9803
# Testing Accuracy: 0.9226
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#          0.0     0.9241    0.9580    0.9407       381
#          1.0     0.9101    0.8912    0.9005       193
#          2.0     0.9326    0.8830    0.9071       188
#
#     accuracy                         0.9226       762
#    macro avg     0.9222    0.9107    0.9161       762
# weighted avg     0.9226    0.9226    0.9222       762

# %%
# ------------------------
# Plot Confusion Matrix
# ------------------------
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(6,5), dpi=300)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap="Blues",
            xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# ------------------------
# Plot Training History
# ------------------------
plt.figure(figsize=(12,5), dpi=300)

# Plot Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# CV for BiLSTM-BiGRU

# %%
from sklearn.model_selection import StratifiedKFold
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Bidirectional, LSTM, GRU, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.utils import to_categorical


# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/eeg-motor-v1/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Get number of unique classes
num_classes = len(np.unique(y))

# Number of folds for cross-validation
K = 10  # You can change this to 10 for more robust results

# Initialize Stratified K-Fold
skf = StratifiedKFold(n_splits=K, shuffle=True, random_state=42)

# Store performance metrics
train_accuracies = []
test_accuracies = []
history_list = []  # To store history for each fold

# ------------------------
# Build the BiLSTM-BiGRU Model
# ------------------------
def build_model(input_shape, num_classes):
    inputs = Input(shape=(input_shape,))
    
    # Wrap tf.expand_dims inside Lambda to expand dimensions
    x = Lambda(lambda t: tf.expand_dims(t, axis=1))(inputs)
    
    # Bi-LSTM layer with L2 regularization and return sequences
    x = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l2(0.01)))(x)
    
    # Bi-GRU layer with return sequences
    x = Bidirectional(GRU(128, return_sequences=False, kernel_regularizer=l2(0.01)))(x)
    
    # Dropout layer for regularization
    x = Dropout(0.2)(x)
    
    # Final dense layer with softmax activation for classification
    outputs = Dense(num_classes, activation="softmax")(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

# Number of folds for cross-validation
K = 10  # You can change this to 10 for more robust results

# Initialize Stratified K-Fold
skf = StratifiedKFold(n_splits=K, shuffle=True, random_state=42)

# Store performance metrics
train_accuracies = []
test_accuracies = []
history_list = []  # To store history for each fold

# Iterate over each fold
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    print(f"\nTraining on Fold {fold + 1}/{K}...\n")
    
    # Get train-test split for current fold
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # Convert labels to categorical for evaluation
    y_train_cat = to_categorical(y_train, num_classes)
    y_test_cat = to_categorical(y_test, num_classes)

    # Build a new model for each fold
    model = build_model(X_train.shape[1], num_classes)

    # Early stopping to prevent overfitting
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Train the model on current fold
    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=250,
        batch_size=128,
        callbacks=[early_stopping],
        verbose=0
    )

    # Store history for later analysis
    history_list.append(history.history)

    # Evaluate model on train and test set
    y_train_pred = np.argmax(model.predict(X_train), axis=1)
    y_test_pred = np.argmax(model.predict(X_test), axis=1)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)

    print(f"Fold {fold + 1} - Training Accuracy: {train_accuracy:.4f}")
    print(f"Fold {fold + 1} - Testing Accuracy: {test_accuracy:.4f}")

    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)

# Compute overall mean accuracy
mean_train_accuracy = np.mean(train_accuracies)
mean_test_accuracy = np.mean(test_accuracies)

print("\n----------------------")
print(f"Mean Training Accuracy: {mean_train_accuracy:.4f}")
print(f"Mean Testing Accuracy: {mean_test_accuracy:.4f}")
print("----------------------")
# Out:
# Training on Fold 1/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 1 - Training Accuracy: 0.9758
# Fold 1 - Testing Accuracy: 0.9108
#
# Training on Fold 2/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 2 - Training Accuracy: 0.9769
# Fold 2 - Testing Accuracy: 0.8871
#
# Training on Fold 3/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 3 - Training Accuracy: 0.9761
# Fold 3 - Testing Accuracy: 0.9239
#
# Training on Fold 4/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 4 - Training Accuracy: 0.9740
# Fold 4 - Testing Accuracy: 0.9029
#
# Training on Fold 5/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 5 - Training Accuracy: 0.9761
# Fold 5 - Testing Accuracy: 0.8871
#
# Training on Fold 6/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 6 - Training Accuracy: 0.9749
# Fold 6 - Testing Accuracy: 0.8976
#
# Training on Fold 7/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 7 - Training Accuracy: 0.9764
# Fold 7 - Testing Accuracy: 0.9081
#
# Training on Fold 8/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 8 - Training Accuracy: 0.9755
# Fold 8 - Testing Accuracy: 0.8976
#
# Training on Fold 9/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 9 - Training Accuracy: 0.9778
# Fold 9 - Testing Accuracy: 0.8921
#
# Training on Fold 10/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 10 - Training Accuracy: 0.9740
# Fold 10 - Testing Accuracy: 0.9053
#
# ----------------------
# Mean Training Accuracy: 0.9758
# Mean Testing Accuracy: 0.9013
# ----------------------

# %%
from sklearn.model_selection import StratifiedKFold
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Bidirectional, LSTM, GRU, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Get number of unique classes
num_classes = len(np.unique(y))

# Number of folds for cross-validation
K = 10 

# Initialize Stratified K-Fold
skf = StratifiedKFold(n_splits=K, shuffle=True, random_state=123)

# Store performance metrics
train_accuracies = []
test_accuracies = []
history_list = []  

# ------------------------
# Build the BiLSTM-BiGRU Model
# ------------------------
def build_model(input_shape, num_classes):
    inputs = Input(shape=(input_shape,))
    
    # Expand dimensions
    x = Lambda(lambda t: tf.expand_dims(t, axis=1))(inputs)
    
    # Bi-LSTM layer with L2 regularization
    x = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l2(0.01)))(x)
    
    # Bi-GRU layer with return sequences
    x = Bidirectional(GRU(128, return_sequences=False, kernel_regularizer=l2(0.01)))(x)
    
    # Dropout for regularization
    x = Dropout(0.2)(x)
    
    # Output layer
    outputs = Dense(num_classes, activation="softmax")(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

# ------------------------
# Cross-Validation Training & Evaluation
# ------------------------
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    print(f"\nTraining on Fold {fold + 1}/{K}...\n")
    
    # Get train-test split for current fold
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # Build a new model for each fold
    model = build_model(X_train.shape[1], num_classes)

    # Early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Train the model
    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=250,
        batch_size=128,
        callbacks=[early_stopping],
        verbose=0  # Silent training for cleaner output
    )

    # Store history
    history_list.append(history.history)

    # Evaluate model
    y_train_pred = np.argmax(model.predict(X_train), axis=1)
    y_test_pred = np.argmax(model.predict(X_test), axis=1)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)

    print(f"Fold {fold + 1} - Training Accuracy: {train_accuracy:.4f}")
    print(f"Fold {fold + 1} - Testing Accuracy: {test_accuracy:.4f}")

    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)

# ------------------------
# Compute Overall Performance
# ------------------------
mean_train_accuracy = np.mean(train_accuracies)
std_train_accuracy = np.std(train_accuracies)

mean_test_accuracy = np.mean(test_accuracies)
std_test_accuracy = np.std(test_accuracies)

print("\n----------------------")
print(f"Mean Training Accuracy: {mean_train_accuracy:.4f} ± {std_train_accuracy:.4f}")
print(f"Mean Testing Accuracy: {mean_test_accuracy:.4f} ± {std_test_accuracy:.4f}")
print("----------------------")
# Out:
# Training on Fold 1/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 1 - Training Accuracy: 0.9758
# Fold 1 - Testing Accuracy: 0.8793
#
# Training on Fold 2/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 2 - Training Accuracy: 0.9775
# Fold 2 - Testing Accuracy: 0.9055
#
# Training on Fold 3/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 3 - Training Accuracy: 0.9775
# Fold 3 - Testing Accuracy: 0.8766
#
# Training on Fold 4/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 4 - Training Accuracy: 0.9752
# Fold 4 - Testing Accuracy: 0.9134
#
# Training on Fold 5/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 5 - Training Accuracy: 0.9787
# Fold 5 - Testing Accuracy: 0.9081
#
# Training on Fold 6/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 6 - Training Accuracy: 0.9752
# Fold 6 - Testing Accuracy: 0.8871
#
# Training on Fold 7/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 7 - Training Accuracy: 0.9767
# Fold 7 - Testing Accuracy: 0.9003
#
# Training on Fold 8/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 8 - Training Accuracy: 0.9761
# Fold 8 - Testing Accuracy: 0.9134
#
# Training on Fold 9/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 9 - Training Accuracy: 0.9761
# Fold 9 - Testing Accuracy: 0.9211
#
# Training on Fold 10/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 10 - Training Accuracy: 0.9752
# Fold 10 - Testing Accuracy: 0.9105
#
# ----------------------
# Mean Training Accuracy: 0.9764 ± 0.0011
# Mean Testing Accuracy: 0.9015 ± 0.0146
# ----------------------

# %% [markdown]
# Transformer-based: https://www.nature.com/articles/s41598-023-41653-w

# %%
# Transformer model usage

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Dense, Dropout, LayerNormalization, GlobalAveragePooling1D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Reshape X to fit Transformer expected input (samples, timesteps, features)
X = np.expand_dims(X, axis=1)  # Now shape: (num_samples, 1, num_features)

# Train-Test Split with Stratification
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, shuffle=True, random_state=42
)

# Convert labels to categorical for evaluation,
# but pass integer labels during training (using np.argmax)
num_classes = len(np.unique(y))
y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

# ------------------------
# Positional Encoding Function
# ------------------------
def positional_encoding(length, depth):
    """
    Generate positional encoding for input sequences.
    """
    pos = np.arange(length)[:, np.newaxis]
    i = np.arange(depth)[np.newaxis, :]
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(depth))
    angle_rads = pos * angle_rates

    # Apply sin to even indices, cos to odd indices
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    return tf.convert_to_tensor(angle_rads, dtype=tf.float32)

# ------------------------
# Transformer Block
# ------------------------
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.6):  # Increased dropout rate
        super(TransformerBlock, self).__init__()
        self.att = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.05)),
            Dense(embed_dim, kernel_regularizer=tf.keras.regularizers.l2(0.05))
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training=False):
        attn_output = self.att(inputs, inputs, training=training)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1, training=training)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# ------------------------
# Transformer Model
# ------------------------
def build_transformer(input_shape, num_classes, embed_dim=32, num_heads=2, ff_dim=64, num_blocks=2, dropout_rate=0.6):
    inputs = Input(shape=input_shape)

    # Positional Encoding
    positions = positional_encoding(input_shape[0], embed_dim)
    x = Dense(embed_dim, kernel_regularizer=tf.keras.regularizers.l2(0.05))(inputs)  # Stronger L2 Regularization
    x += positions  # Add positional encodings

    # Transformer Blocks
    for _ in range(num_blocks):
        x = TransformerBlock(embed_dim, num_heads, ff_dim, dropout_rate)(x)

    # Classification Head
    x = GlobalAveragePooling1D()(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(num_classes, activation="softmax", kernel_regularizer=tf.keras.regularizers.l2(0.05))(x)

    return Model(inputs, outputs)

# ------------------------
# Build and Train the Model
# ------------------------
input_shape = (X_train.shape[1], X_train.shape[2])  # (timesteps, features)
model = build_transformer(input_shape, num_classes)

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(X_train, y_train,
                    validation_split=0.2,
                    epochs=500,
                    batch_size=128,
                    callbacks=[early_stopping],
                    verbose=1)

# ------------------------
# Evaluate the Model
# ------------------------
y_train_pred = np.argmax(model.predict(X_train), axis=1)
y_test_pred = np.argmax(model.predict(X_test), axis=1)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Testing Accuracy: {test_accuracy:.4f}")

from sklearn.metrics import classification_report

# Print classification report for the test set
print("\nClassification Report (Test Set):")
print(classification_report(y_test, y_test_pred, digits=4))

# ------------------------
# Plot Confusion Matrix
# ------------------------
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(6,5), dpi=300)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap="Blues",
            xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# ------------------------
# Plot Training History
# ------------------------
plt.figure(figsize=(12,5), dpi=300)

# Plot Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# Epoch 1/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 279ms/step - accuracy: 0.3755 - loss: 13.8882 - val_accuracy: 0.6131 - val_loss: 12.8533
# Epoch 2/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4607 - loss: 13.3808 - val_accuracy: 0.6885 - val_loss: 12.5240
# Epoch 3/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5160 - loss: 13.0049 - val_accuracy: 0.7197 - val_loss: 12.2654
# Epoch 4/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5580 - loss: 12.7037 - val_accuracy: 0.7557 - val_loss: 12.0330
# Epoch 5/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5693 - loss: 12.4537 - val_accuracy: 0.7672 - val_loss: 11.8274
# Epoch 6/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6156 - loss: 12.1834 - val_accuracy: 0.7836 - val_loss: 11.6106
# Epoch 7/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6326 - loss: 11.9620 - val_accuracy: 0.7820 - val_loss: 11.3981
# Epoch 8/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6856 - loss: 11.6418 - val_accuracy: 0.7902 - val_loss: 11.2135
# Epoch 9/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6696 - loss: 11.4939 - val_accuracy: 0.8016 - val_loss: 11.0193
# Epoch 10/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6900 - loss: 11.2159 - val_accuracy: 0.8066 - val_loss: 10.8471
# Epoch 11/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7133 - loss: 10.9879 - val_accuracy: 0.8082 - val_loss: 10.6760
# Epoch 12/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7369 - loss: 10.7720 - val_accuracy: 0.8148 - val_loss: 10.4903
# Epoch 13/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7494 - loss: 10.5805 - val_accuracy: 0.8246 - val_loss: 10.2997
# Epoch 14/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7557 - loss: 10.4196 - val_accuracy: 0.8197 - val_loss: 10.1261
# Epoch 15/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7642 - loss: 10.1910 - val_accuracy: 0.8279 - val_loss: 9.9545
# Epoch 16/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7827 - loss: 10.0410 - val_accuracy: 0.8295 - val_loss: 9.7926
# Epoch 17/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8005 - loss: 9.8197 - val_accuracy: 0.8295 - val_loss: 9.6311
# Epoch 18/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7826 - loss: 9.6898 - val_accuracy: 0.8328 - val_loss: 9.4679
# Epoch 19/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8042 - loss: 9.4970 - val_accuracy: 0.8426 - val_loss: 9.2997
# Epoch 20/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8129 - loss: 9.2822 - val_accuracy: 0.8443 - val_loss: 9.1502
# Epoch 21/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8203 - loss: 9.1191 - val_accuracy: 0.8361 - val_loss: 8.9970
# Epoch 22/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8221 - loss: 8.9622 - val_accuracy: 0.8443 - val_loss: 8.8418
# Epoch 23/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8533 - loss: 8.7320 - val_accuracy: 0.8492 - val_loss: 8.6834
# Epoch 24/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8425 - loss: 8.6252 - val_accuracy: 0.8459 - val_loss: 8.5282
# Epoch 25/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9756 - loss: 1.9195 - val_accuracy: 0.8902 - val_loss: 2.1974
# Epoch 95/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9792 - loss: 1.8696 - val_accuracy: 0.8902 - val_loss: 2.1464
# Epoch 96/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9809 - loss: 1.8266 - val_accuracy: 0.8934 - val_loss: 2.1078
# Epoch 97/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9756 - loss: 1.7880 - val_accuracy: 0.8934 - val_loss: 2.0654
# Epoch 98/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9713 - loss: 1.7503 - val_accuracy: 0.8885 - val_loss: 2.0185
# Epoch 99/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9829 - loss: 1.6954 - val_accuracy: 0.8951 - val_loss: 1.9828
# Epoch 100/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9836 - loss: 1.6564 - val_accuracy: 0.8885 - val_loss: 1.9373
# Epoch 101/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9781 - loss: 1.6240 - val_accuracy: 0.8787 - val_loss: 1.9195
# Epoch 102/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9821 - loss: 1.5798 - val_accuracy: 0.8820 - val_loss: 1.8720
# Epoch 103/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9705 - loss: 1.5546 - val_accuracy: 0.8852 - val_loss: 1.8436
# Epoch 104/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9809 - loss: 1.5098 - val_accuracy: 0.8787 - val_loss: 1.8094
# Epoch 105/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9533 - loss: 1.5419 - val_accuracy: 0.8623 - val_loss: 1.7979
# Epoch 106/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9657 - loss: 1.4780 - val_accuracy: 0.8820 - val_loss: 1.7283
# Epoch 107/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9733 - loss: 1.4196 - val_accuracy: 0.8852 - val_loss: 1.7041
# Epoch 108/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9819 - loss: 1.3743 - val_accuracy: 0.8836 - val_loss: 1.6689
# Epoch 109/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9860 - loss: 1.3326 - val_accuracy: 0.8852 - val_loss: 1.6379
# Epoch 110/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9871 - loss: 1.2940 - val_accuracy: 0.8852 - val_loss: 1.6117
# Epoch 111/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9846 - loss: 1.2585 - val_accuracy: 0.8820 - val_loss: 1.5769
# Epoch 112/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9845 - loss: 1.2294 - val_accuracy: 0.8918 - val_loss: 1.5332
# Epoch 113/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9751 - loss: 1.2340 - val_accuracy: 0.8770 - val_loss: 1.5139
# Epoch 114/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9772 - loss: 1.2000 - val_accuracy: 0.8852 - val_loss: 1.4899
# Epoch 115/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9668 - loss: 1.1893 - val_accuracy: 0.8738 - val_loss: 1.4944
# Epoch 116/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9667 - loss: 1.1601 - val_accuracy: 0.8820 - val_loss: 1.4408
# Epoch 117/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9859 - loss: 1.1008 - val_accuracy: 0.8934 - val_loss: 1.4004
# Epoch 118/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9873 - loss: 1.0730 - val_accuracy: 0.8902 - val_loss: 1.3833
# Epoch 119/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9861 - loss: 1.0487 - val_accuracy: 0.8967 - val_loss: 1.3545
# Epoch 120/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9775 - loss: 1.0377 - val_accuracy: 0.8803 - val_loss: 1.3461
# Epoch 121/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9876 - loss: 0.9930 - val_accuracy: 0.8852 - val_loss: 1.3258
# Epoch 122/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9873 - loss: 0.9747 - val_accuracy: 0.8852 - val_loss: 1.2981
# Epoch 123/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9850 - loss: 0.9557 - val_accuracy: 0.8836 - val_loss: 1.2830
# Epoch 124/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9890 - loss: 0.9209 - val_accuracy: 0.8836 - val_loss: 1.2638
# Epoch 125/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9847 - loss: 0.8996 - val_accuracy: 0.8885 - val_loss: 1.2319
# Epoch 126/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.8771 - val_accuracy: 0.8852 - val_loss: 1.2127
# Epoch 127/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9904 - loss: 0.8568 - val_accuracy: 0.8787 - val_loss: 1.1893
# Epoch 128/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9880 - loss: 0.8346 - val_accuracy: 0.8836 - val_loss: 1.1669
# Epoch 129/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9887 - loss: 0.8121 - val_accuracy: 0.8820 - val_loss: 1.1509
# Epoch 130/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9895 - loss: 0
500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9829 - loss: 0.3838 - val_accuracy: 0.8918 - val_loss: 0.7035
# Epoch 169/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9906 - loss: 0.3704 - val_accuracy: 0.8902 - val_loss: 0.6903
# Epoch 170/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9890 - loss: 0.3595 - val_accuracy: 0.8918 - val_loss: 0.6834
# Epoch 171/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9892 - loss: 0.3558 - val_accuracy: 0.8934 - val_loss: 0.6806
# Epoch 172/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9910 - loss: 0.3425 - val_accuracy: 0.8967 - val_loss: 0.6761
# Epoch 173/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.3248 - val_accuracy: 0.8967 - val_loss: 0.6724
# Epoch 174/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9869 - loss: 0.3368 - val_accuracy: 0.8902 - val_loss: 0.6696
# Epoch 175/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9897 - loss: 0.3312 - val_accuracy: 0.8934 - val_loss: 0.6588
# Epoch 176/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9921 - loss: 0.3213 - val_accuracy: 0.8820 - val_loss: 0.6632
# Epoch 177/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9848 - loss: 0.3289 - val_accuracy: 0.8803 - val_loss: 0.6701
# Epoch 178/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9866 - loss: 0.3187 - val_accuracy: 0.8902 - val_loss: 0.6460
# Epoch 179/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9913 - loss: 0.3106 - val_accuracy: 0.8934 - val_loss: 0.6572
# Epoch 180/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.3059 - val_accuracy: 0.8951 - val_loss: 0.6513
# Epoch 181/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9969 - loss: 0.2961 - val_accuracy: 0.8967 - val_loss: 0.6434
# Epoch 182/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9938 - loss: 0.2898 - val_accuracy: 0.8869 - val_loss: 0.6521
# Epoch 183/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9956 - loss: 0.2916 - val_accuracy: 0.8902 - val_loss: 0.6287
# Epoch 184/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9935 - loss: 0.2901 - val_accuracy: 0.8934 - val_loss: 0.6277
# Epoch 185/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.2704 - val_accuracy: 0.8984 - val_loss: 0.6305
# Epoch 186/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9971 - loss: 0.2661 - val_accuracy: 0.9000 - val_loss: 0.6248
# Epoch 187/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9961 - loss: 0.2603 - val_accuracy: 0.8852 - val_loss: 0.6341
# Epoch 188/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9921 - loss: 0.2702 - val_accuracy: 0.8885 - val_loss: 0.6350
# Epoch 189/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9896 - loss: 0.2699 - val_accuracy: 0.8885 - val_loss: 0.6211
# Epoch 190/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9942 - loss: 0.2632 - val_accuracy: 0.8902 - val_loss: 0.5946
# Epoch 191/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9944 - loss: 0.2513 - val_accuracy: 0.8885 - val_loss: 0.5957
# Epoch 192/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9868 - loss: 0.2699 - val_accuracy: 0.8623 - val_loss: 0.6504
# Epoch 193/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8489 - loss: 0.7167 - val_accuracy: 0.7984 - val_loss: 0.9016
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Training Accuracy: 0.9773
# Testing Accuracy: 0.8819
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#          0.0     0.8992    0.9134    0.9063       381
#          1.0     0.8267    0.8653    0.8456       193
#          2.0     0.9075    0.8351    0.8698       188
#
#     accuracy                         0.8819       762
#    macro avg     0.8778    0.8713    0.8739       762
# weighted avg     0.8829    0.8819    0.8819       762

# %%
# Transformer model usage

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Dense, Dropout, LayerNormalization, GlobalAveragePooling1D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Reshape X to fit Transformer expected input (samples, timesteps, features)
X = np.expand_dims(X, axis=1)  # Now shape: (num_samples, 1, num_features)

# Train-Test Split with Stratification
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, shuffle=True, random_state=42
)

# Convert labels to categorical for evaluation,
# but pass integer labels during training (using np.argmax)
num_classes = len(np.unique(y))
y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

# ------------------------
# Positional Encoding Function
# ------------------------
def positional_encoding(length, depth):
    """
    Generate positional encoding for input sequences.
    """
    pos = np.arange(length)[:, np.newaxis]
    i = np.arange(depth)[np.newaxis, :]
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(depth))
    angle_rads = pos * angle_rates

    # Apply sin to even indices, cos to odd indices
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    return tf.convert_to_tensor(angle_rads, dtype=tf.float32)

# ------------------------
# Transformer Block
# ------------------------
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.6):  # Increased dropout rate
        super(TransformerBlock, self).__init__()
        self.att = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.05)),
            Dense(embed_dim, kernel_regularizer=tf.keras.regularizers.l2(0.05))
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training=False):
        attn_output = self.att(inputs, inputs, training=training)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1, training=training)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# ------------------------
# Transformer Model
# ------------------------
def build_transformer(input_shape, num_classes, embed_dim=32, num_heads=2, ff_dim=64, num_blocks=2, dropout_rate=0.6):
    inputs = Input(shape=input_shape)

    # Positional Encoding
    positions = positional_encoding(input_shape[0], embed_dim)
    x = Dense(embed_dim, kernel_regularizer=tf.keras.regularizers.l2(0.05))(inputs)  # Stronger L2 Regularization
    x += positions  # Add positional encodings

    # Transformer Blocks
    for _ in range(num_blocks):
        x = TransformerBlock(embed_dim, num_heads, ff_dim, dropout_rate)(x)

    # Classification Head
    x = GlobalAveragePooling1D()(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(num_classes, activation="softmax", kernel_regularizer=tf.keras.regularizers.l2(0.05))(x)

    return Model(inputs, outputs)

# ------------------------
# Build and Train the Model
# ------------------------
input_shape = (X_train.shape[1], X_train.shape[2])  # (timesteps, features)
model = build_transformer(input_shape, num_classes)

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(X_train, y_train,
                    validation_split=0.2,
                    epochs=500,
                    batch_size=128,
                    callbacks=[early_stopping],
                    verbose=1)

# ------------------------
# Evaluate the Model
# ------------------------
y_train_pred = np.argmax(model.predict(X_train), axis=1)
y_test_pred = np.argmax(model.predict(X_test), axis=1)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Testing Accuracy: {test_accuracy:.4f}")

from sklearn.metrics import classification_report

# Print classification report for the test set
print("\nClassification Report (Test Set):")
print(classification_report(y_test, y_test_pred, digits=4))

# ------------------------
# Plot Confusion Matrix
# ------------------------
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(6,5), dpi=300)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap="Blues",
            xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# ------------------------
# Plot Training History
# ------------------------
plt.figure(figsize=(12,5), dpi=300)

# Plot Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# 2025-04-27 02:11:33.285829: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745719893.478923      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745719893.534857      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1745719908.824774      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745719919.314097      92 service.cc:148] XLA service 0x7893a420f110 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745719919.314871      92 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745719920.153719      92 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 15/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3842 - loss: 13.8955
# I0000 00:00:1745719924.196340      92 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 325ms/step - accuracy: 0.3977 - loss: 13.8182 - val_accuracy: 0.6262 - val_loss: 12.8140
# Epoch 2/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5274 - loss: 13.1894 - val_accuracy: 0.6984 - val_loss: 12.4647
# Epoch 3/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5666 - loss: 12.8652 - val_accuracy: 0.7443 - val_loss: 12.1876
# Epoch 4/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6017 - loss: 12.5852 - val_accuracy: 0.7590 - val_loss: 11.9459
# Epoch 5/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6386 - loss: 12.2951 - val_accuracy: 0.7885 - val_loss: 11.7157
# Epoch 6/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6546 - loss: 12.0810 - val_accuracy: 0.8049 - val_loss: 11.5113
# Epoch 7/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6711 - loss: 11.8176 - val_accuracy: 0.8131 - val_loss: 11.3281
# Epoch 8/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6919 - loss: 11.6526 - val_accuracy: 0.8180 - val_loss: 11.1496
# Epoch 9/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6961 - loss: 11.4022 - val_accuracy: 0.8262 - val_loss: 10.9766
# Epoch 10/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7302 - loss: 11.1772 - val_accuracy: 0.8279 - val_loss: 10.8067
# Epoch 11/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7666 - loss: 10.9135 - val_accuracy: 0.8328 - val_loss: 10.6204
# Epoch 12/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7650 - loss: 10.7447 - val_accuracy: 0.8426 - val_loss: 10.4529
# Epoch 13/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7639 - loss: 10.5715 - val_accuracy: 0.8410 - val_loss: 10.2870
# Epoch 14/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7846 - loss: 10.3560 - val_accuracy: 0.8443 - val_loss: 10.1243
# Epoch 15/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7886 - loss: 10.2112 - val_accuracy: 0.8492 - val_loss: 9.9612
# Epoch 16/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8142 - loss: 9.9973 - val_accuracy: 0.8525 - val_loss: 9.7904
# Epoch 17/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8062 - loss: 9.8333 - val_accuracy: 0.8607 - val_loss: 9.6218
# Epoch 18/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8187 - loss: 9.6596 - val_accuracy: 0.8656 - val_loss: 9.4611
# Epoch 19/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8220 - loss: 9.4745 - val_accuracy: 0.8639 - val_loss: 9.3157
# Epoch 20/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8496 - loss: 9.2750 - val_accuracy: 0.8672 - val_loss: 9.1551
# Epoch 21/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8362 - loss: 9.1255 - val_accuracy: 0.8672 - val_loss: 8.9994
# Epoch 22/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8653 - loss: 8.9199 - val_accuracy: 0.8639 - val_loss: 8.8423
# Epoch 23/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8495 - loss: 8.8187 - val_accuracy: 0.8672 - val_loss: 8.6861
# Epoch 24/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8613 - loss: 8.6446 - val_accuracy: 0.8672 - val_loss: 8.5391
# Epoch 25/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8692 - loss:
500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9600 - loss: 4.2904 - val_accuracy: 0.8852 - val_loss: 4.4712
# Epoch 60/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9608 - loss: 4.1970 - val_accuracy: 0.8820 - val_loss: 4.3848
# Epoch 61/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9698 - loss: 4.1003 - val_accuracy: 0.8787 - val_loss: 4.3063
# Epoch 62/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9605 - loss: 4.0124 - val_accuracy: 0.8770 - val_loss: 4.2189
# Epoch 63/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9644 - loss: 3.9458 - val_accuracy: 0.8787 - val_loss: 4.1360
# Epoch 64/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9661 - loss: 3.8675 - val_accuracy: 0.8820 - val_loss: 4.0529
# Epoch 65/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9567 - loss: 3.7850 - val_accuracy: 0.8689 - val_loss: 3.9998
# Epoch 66/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9499 - loss: 3.7246 - val_accuracy: 0.8787 - val_loss: 3.9038
# Epoch 67/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9627 - loss: 3.6087 - val_accuracy: 0.8803 - val_loss: 3.8127
# Epoch 68/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9498 - loss: 3.5766 - val_accuracy: 0.8787 - val_loss: 3.7424
# Epoch 69/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9626 - loss: 3.4686 - val_accuracy: 0.8967 - val_loss: 3.6489
# Epoch 70/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9700 - loss: 3.3924 - val_accuracy: 0.8918 - val_loss: 3.5781
# Epoch 71/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9727 - loss: 3.3169 - val_accuracy: 0.8951 - val_loss: 3.5075
# Epoch 72/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9668 - loss: 3.2557 - val_accuracy: 0.8934 - val_loss: 3.4439
# Epoch 73/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9672 - loss: 3.1675 - val_accuracy: 0.8902 - val_loss: 3.3817
# Epoch 74/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9718 - loss: 3.0896 - val_accuracy: 0.8918 - val_loss: 3.3142
# Epoch 75/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9764 - loss: 3.0147 - val_accuracy: 0.8885 - val_loss: 3.2510
# Epoch 76/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9692 - loss: 2.9675 - val_accuracy: 0.8852 - val_loss: 3.1777
# Epoch 77/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9779 - loss: 2.8774 - val_accuracy: 0.8885 - val_loss: 3.1203
# Epoch 78/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9769 - loss: 2.8301 - val_accuracy: 0.8902 - val_loss: 3.0558
# Epoch 79/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9804 - loss: 2.7458 - val_accuracy: 0.8885 - val_loss: 3.0028
# Epoch 80/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9834 - loss: 2.6915 - val_accuracy: 0.8869 - val_loss: 2.9293
# Epoch 81/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9792 - loss: 2.6448 - val_accuracy: 0.8836 - val_loss: 2.8781
# Epoch 82/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9737 - loss: 2.5851 - val_accuracy: 0.8869 - val_loss: 2.8208
# Epoch 83/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9859 - loss: 2.5083 - val_accuracy: 0.8902 - val_loss: 2.7553
# Epoch 84/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9593 - loss: 2.5166 - val_accuracy: 0.8820 - val_loss: 2.7156
# Epoch 85/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9699 - loss: 2.4520 - val_accuracy: 0.8787 - val_loss: 2.6480
# Epoch 86/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9719 - loss: 2.3737 - val_accuracy: 0.8885 - val_loss: 2.5931
# Epoch 87/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9737 - loss: 2.3095 - val_accuracy: 0.8902 - val_loss: 2.5434
# Epoch 88/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9821 - loss: 2.2489 - val_accuracy: 0.8885 - val_loss: 2.5032
# Epoch 89/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9870 - loss: 2.1845 - val_accuracy: 0.8902 - val_loss: 2.4426
# Epoch 90/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9847 - loss: 2.1462 - val_accuracy: 0.8902 - val_loss: 2.3909
# Epoch 91/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9868 - loss: 2.0977 - val_accuracy: 0.8934 - val_loss: 2.3481
# Epoch 92/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9671 - loss: 2.0839 - val_accuracy: 0.8803 - val_loss: 2.3335
# Epoch 93/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9657 - loss: 2.0397 - val_accuracy: 0.8820 - val_loss: 2.2852
# Epoch 94/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9731 - loss: 1.9855 - val_accuracy: 0.8852 - val_loss: 2.2387
# Epoch 95/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9793 - loss: 1.9276 - val_accuracy: 0.8820 - val_loss: 2.1824
# Epoch 96/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9799 - loss: 1.8802 - val_accuracy: 0.8721 - val_loss: 2.1443
# Epoch 97/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9740 - loss: 1.8534 - val_accuracy: 0.8869 - val_loss: 2.1069
# Epoch 98/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9761 - loss: 1.8042 - val_accuracy: 0.8852 - val_loss: 2.0656
# Epoch 99/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9793 - loss: 1.7600 - val_accuracy: 0.8885 - val_loss: 2.0142
# Epoch 100/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9792 - loss: 1.7235 - val_accuracy: 0.8902 - val_loss: 1.9918
# Epoch 101/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9714 - loss: 1.6932 - val_accuracy: 0.8934 - val_loss: 1.9471
# Epoch 102/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9755 - loss: 1.6499 - val_accuracy: 0.8918 - val_loss: 1.9006
# Epoch 103/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9848 - loss: 1.5894 - val_accuracy: 0.9000 - val_loss: 1.8678
# Epoch 104/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9804 - loss: 1.5614 - val_accuracy: 0.8951 - val_loss: 1.8313
# Epoch 105/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9884 - loss: 1.5179 - val_accuracy: 0.8902 - val_loss: 1.7982
# Epoch 106/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9843 - loss: 1.4866 - val_accuracy: 0.8918 - val_loss: 1.7651
# Epoch 107/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 1.4363 - val_accuracy: 0.8934 - val_loss: 1.7331
# Epoch 108/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9871 - loss: 1.4124 - val_accuracy: 0.8951 - val_loss: 1.6989
# Epoch 109/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9881 - loss: 1.3769 - val_accuracy: 0.8967 - val_loss: 1.6695
# Epoch 110/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9889 - loss: 1.3475 - val_accuracy: 0.8951 - val_loss: 1.6391
# Epoch 111/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9868 - loss: 1.3122 - val_accuracy: 0.8902 - val_loss: 1.6027
# Epoch 112/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9866 - loss: 1.2837 - val_accuracy: 0.8803 - val_loss: 1.5875
# Epoch 113/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9837 - loss: 1.2586 - val_accuracy: 0.8820 - val_loss: 1.5547
# Epoch 114/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9603 - loss: 1.2903 - val_accuracy: 0.8803 - val_loss: 1.5566
# Epoch 115/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9672 - loss: 1.2486 - val_accuracy: 0.8951 - val_loss: 1.5166
# Epoch 116/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9845 - loss: 1.1791 - val_accuracy: 0.8934 - val_loss: 1.4737
# Epoch 117/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9870 - loss: 1.1605 - val_accuracy: 0.8918 - val_loss: 1.4616
# Epoch 118/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9873 - loss: 1.1242 - val_accuracy: 0.8885 - val_loss: 1.4304
# Epoch 119/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9864 - loss: 1.0959 - val_accuracy: 0.8869 - val_loss: 1.4068
# Epoch 120/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9799 - loss: 1.0828 - val_accuracy: 0.8852 - val_loss: 1.3805
# Epoch 121/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9854 - loss: 1.0485 - val_accuracy: 0.8885 - val_loss: 1.3465
# Epoch 122/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9850 - loss: 1.0214 - val_accuracy: 0.8918 - val_loss: 1.3294
# Epoch 123/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9948 - loss: 0.9889 - val_accuracy: 0.8885 - val_loss: 1.3008
# Epoch 124/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9914 - loss: 0.9696 - val_accuracy: 0.8852 - val_loss: 1.2843
# Epoch 125/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9909 - loss: 0.9501 - val_accuracy: 0.8918 - val_loss: 1.2577
# Epoch 126/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9874 - loss: 0.9339 - val_accuracy: 0.8885 - val_loss: 1.2394
# Epoch 127/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9903 - loss: 0.9030 - val_accuracy: 0.8885 - val_loss: 1.2230
# Epoch 128/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9861 - loss: 0.8900 - val_accuracy: 0.8803 - val_loss: 1.2069
# Epoch 129/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9862 - loss: 0.8741 - val_accuracy: 0.8934 - val_loss: 1.1908
# Epoch 130/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9899 - loss: 0.8461 - val_accuracy: 0.8836 - val_loss: 1.1610
# Epoch 131/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9854 - loss: 0
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#          0.0     0.9060    0.9108    0.9084       381
#          1.0     0.8267    0.8653    0.8456       193
#          2.0     0.8701    0.8191    0.8438       188
#
#     accuracy                         0.8766       762
#    macro avg     0.8676    0.8651    0.8659       762
# weighted avg     0.8771    0.8766    0.8765       762

# %%
# Transformer model usage

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Dense, Dropout, LayerNormalization, GlobalAveragePooling1D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Reshape X to fit Transformer expected input (samples, timesteps, features)
X = np.expand_dims(X, axis=1)  # Now shape: (num_samples, 1, num_features)

# Train-Test Split with Stratification
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, shuffle=True, random_state=42
)

# Convert labels to categorical for evaluation,
# but pass integer labels during training (using np.argmax)
num_classes = len(np.unique(y))
y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

# ------------------------
# Positional Encoding Function
# ------------------------
def positional_encoding(length, depth):
    """
    Generate positional encoding for input sequences.
    """
    pos = np.arange(length)[:, np.newaxis]
    i = np.arange(depth)[np.newaxis, :]
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(depth))
    angle_rads = pos * angle_rates

    # Apply sin to even indices, cos to odd indices
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    return tf.convert_to_tensor(angle_rads, dtype=tf.float32)

# ------------------------
# Transformer Block
# ------------------------
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.6):  # Increased dropout rate
        super(TransformerBlock, self).__init__()
        self.att = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.05)),
            Dense(embed_dim, kernel_regularizer=tf.keras.regularizers.l2(0.05))
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training=False):
        attn_output = self.att(inputs, inputs, training=training)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1, training=training)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# ------------------------
# Transformer Model
# ------------------------
def build_transformer(input_shape, num_classes, embed_dim=32, num_heads=2, ff_dim=64, num_blocks=2, dropout_rate=0.6):
    inputs = Input(shape=input_shape)

    # Positional Encoding
    positions = positional_encoding(input_shape[0], embed_dim)
    x = Dense(embed_dim, kernel_regularizer=tf.keras.regularizers.l2(0.05))(inputs)  # Stronger L2 Regularization
    x += positions  # Add positional encodings

    # Transformer Blocks
    for _ in range(num_blocks):
        x = TransformerBlock(embed_dim, num_heads, ff_dim, dropout_rate)(x)

    # Classification Head
    x = GlobalAveragePooling1D()(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(num_classes, activation="softmax", kernel_regularizer=tf.keras.regularizers.l2(0.05))(x)

    return Model(inputs, outputs)

# ------------------------
# Build and Train the Model
# ------------------------
input_shape = (X_train.shape[1], X_train.shape[2])  # (timesteps, features)
model = build_transformer(input_shape, num_classes)

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train,
                    validation_split=0.2,
                    epochs=500,
                    batch_size=128,
                    callbacks=[early_stopping],
                    verbose=1)

# ------------------------
# Evaluate the Model
# ------------------------
y_train_pred = np.argmax(model.predict(X_train), axis=1)
y_test_pred = np.argmax(model.predict(X_test), axis=1)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Testing Accuracy: {test_accuracy:.4f}")

from sklearn.metrics import classification_report

# Print classification report for the test set
print("\nClassification Report (Test Set):")
print(classification_report(y_test, y_test_pred, digits=4))


# ------------------------
# Plot Confusion Matrix
# ------------------------
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(6,5), dpi=300)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap="Blues",
            xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# ------------------------
# Plot Training History
# ------------------------
plt.figure(figsize=(12,5), dpi=300)

# Plot Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# Epoch 1/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 260ms/step - accuracy: 0.3330 - loss: 14.1800 - val_accuracy: 0.4672 - val_loss: 13.0673
# Epoch 2/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4258 - loss: 13.6122 - val_accuracy: 0.6082 - val_loss: 12.6152
# Epoch 3/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5008 - loss: 13.1054 - val_accuracy: 0.6689 - val_loss: 12.3489
# Epoch 4/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5356 - loss: 12.8974 - val_accuracy: 0.7082 - val_loss: 12.1069
# Epoch 5/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5543 - loss: 12.5661 - val_accuracy: 0.7541 - val_loss: 11.8717
# Epoch 6/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5882 - loss: 12.3296 - val_accuracy: 0.7721 - val_loss: 11.6651
# Epoch 7/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6016 - loss: 12.0443 - val_accuracy: 0.7852 - val_loss: 11.4590
# Epoch 8/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6294 - loss: 11.8393 - val_accuracy: 0.7951 - val_loss: 11.2647
# Epoch 9/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6518 - loss: 11.6343 - val_accuracy: 0.8016 - val_loss: 11.0801
# Epoch 10/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6791 - loss: 11.3911 - val_accuracy: 0.8082 - val_loss: 10.8987
# Epoch 11/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7037 - loss: 11.1107 - val_accuracy: 0.8131 - val_loss: 10.7239
# Epoch 12/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7233 - loss: 10.9076 - val_accuracy: 0.8180 - val_loss: 10.5514
# Epoch 13/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7382 - loss: 10.6952 - val_accuracy: 0.8262 - val_loss: 10.3738
# Epoch 14/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7547 - loss: 10.4769 - val_accuracy: 0.8295 - val_loss: 10.2009
# Epoch 15/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7477 - loss: 10.3771 - val_accuracy: 0.8443 - val_loss: 10.0342
# Epoch 16/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7853 - loss: 10.1057 - val_accuracy: 0.8475 - val_loss: 9.8765
# Epoch 17/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7840 - loss: 9.9210 - val_accuracy: 0.8475 - val_loss: 9.7184
# Epoch 18/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7710 - loss: 9.8105 - val_accuracy: 0.8492 - val_loss: 9.5680
# Epoch 19/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9642 - loss: 2.5213 - val_accuracy: 0.8836 - val_loss: 2.7414
# Epoch 87/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9769 - loss: 2.4431 - val_accuracy: 0.8820 - val_loss: 2.6951
# Epoch 88/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9698 - loss: 2.4134 - val_accuracy: 0.8934 - val_loss: 2.6308
# Epoch 89/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9685 - loss: 2.3384 - val_accuracy: 0.8951 - val_loss: 2.5838
# Epoch 90/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9775 - loss: 2.2803 - val_accuracy: 0.8934 - val_loss: 2.5328
# Epoch 91/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9737 - loss: 2.2401 - val_accuracy: 0.8902 - val_loss: 2.4672
# Epoch 92/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9765 - loss: 2.1939 - val_accuracy: 0.8902 - val_loss: 2.4240
# Epoch 93/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9688 - loss: 2.1491 - val_accuracy: 0.8852 - val_loss: 2.3842
# Epoch 94/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9795 - loss: 2.0962 - val_accuracy: 0.8852 - val_loss: 2.3370
# Epoch 95/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9733 - loss: 2.0400 - val_accuracy: 0.8885 - val_loss: 2.2916
# Epoch 96/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9801 - loss: 1.9897 - val_accuracy: 0.8951 - val_loss: 2.2518
# Epoch 97/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9752 - loss: 1.9495 - val_accuracy: 0.8852 - val_loss: 2.2155
# Epoch 98/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9785 - loss: 1.9065 - val_accuracy: 0.8787 - val_loss: 2.1796
# Epoch 99/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9837 - loss: 1.8464 - val_accuracy: 0.8902 - val_loss: 2.1259
# Epoch 100/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9770 - loss: 1.8248 - val_accuracy: 0.8770 - val_loss: 2.0841
# Epoch 101/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9781 - loss: 1.7733 - val_accuracy: 0.8852 - val_loss: 2.0359
# Epoch 102/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9827 - loss: 1.7278 - val_accuracy: 0.8934 - val_loss: 1.9894
# Epoch 103/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9858 - loss: 1.6799 - val_accuracy: 0.8934 - val_loss: 1.9574
# Epoch 104/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9839 - loss: 1.6498 - val_accuracy: 0.8902 - val_loss: 1.9193
# Epoch 105/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9809 - loss: 1.6097 - val_accuracy: 0.8918 - val_loss: 1.8775
# Epoch 106/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9680 - loss: 1.6029 - val_accuracy: 0.8770 - val_loss: 1.8579
# Epoch 107/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9757 - loss: 1.5427 - val_accuracy: 0.8885 - val_loss: 1.8127
# Epoch 108/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9771 - loss: 1.5085 - val_accuracy: 0.8820 - val_loss: 1.7880
# Epoch 109/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9847 - loss: 1.4609 - val_accuracy: 0.8869 - val_loss: 1.7470
# Epoch 110/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9858 - loss: 1.4262 - val_accuracy: 0.8885 - val_loss: 1.7151
# Epoch 111/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9849 - loss: 1.3962 - val_accuracy: 0.8967 - val_loss: 1.6684
# Epoch 112/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9828 - loss: 1.3576 - val_accuracy: 0.8918 - val_loss: 1.6558
# Epoch 113/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9838 - loss: 1.3261 - val_accuracy: 0.8869 - val_loss: 1.6173
# Epoch 114/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9835 - loss: 1.2956 - val_accuracy: 0.8852 - val_loss: 1.6020
# Epoch 115/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9860 - loss: 1.2639 - val_accuracy: 0.8902 - val_loss: 1.5643
# Epoch 116/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9885 - loss: 1.2295 - val_accuracy: 0.8902 - val_loss: 1.5592
# Epoch 117/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9836 - loss: 1.2083 - val_accuracy: 0.8869 - val_loss: 1.5111
# Epoch 118/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9752 - loss: 1.1973 - val_accuracy: 0.8836 - val_loss: 1.4891
# Epoch 119/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9750 - loss: 1.1832 - val_accuracy: 0.8852 - val_loss: 1.4634
# Epoch 120/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9617 - loss: 1.1884 - val_accuracy: 0.8820 - val_loss: 1.4450
# Epoch 121/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9672 - loss: 1.1401 - val_accuracy: 0.8836 - val_loss: 1.3974
# Epoch 122/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9669 - loss: 1.1033 - val_accuracy: 0.8951 - val_loss: 1.3548
# Epoch 123/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9809 - loss: 1.0621 - val_accuracy: 0.9033 - val_loss: 1.3250
# Epoch 124/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9819 - loss: 1.0424 - val_accuracy: 0.9016 - val_loss: 1.2993
# Epoch 125/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9846 - loss: 1.0087 - val_accuracy: 0.8918 - val_loss: 1.2836
# Epoch 126/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9840 - loss: 0.9911 - val_accuracy: 0.8984 - val_loss: 1.2763
# Epoch 127/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9857 - loss: 0.9623 - val_accuracy: 0.8967 - val_loss: 1.2448
# Epoch 128/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9840 - loss: 0.9377 - val_accuracy: 0.8820 - val_loss: 1.2241
# Epoch 129/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.9079 - val_accuracy: 0.8918 - val_loss: 1.2037
# Epoch 130/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9884 - loss: 0.8842 - val_accuracy: 0.8836 - val_loss: 1.1853
# Epoch 131/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9812 - loss: 0.8955 - val_accuracy: 0.8721 - val_loss: 1.2120
# Epoch 132/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9631 - loss: 0.9119 - val_accuracy: 0.8705 - val_loss: 1.2023
# Epoch 133/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9695 - loss: 0.8808 - val_accuracy: 0.8738 - val_loss: 1.1629
# Epoch 134/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9730 - loss: 0.8653 - val_accuracy: 0.8754 - val_loss: 1.1407
# Epoch 135/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9811 - loss: 0.8143 - val_accuracy: 0.8836 - val_loss: 1.1161
# Epoch 136/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9824 - loss: 0.7983 - val_accuracy: 0.8885 - val_loss: 1.0830
# Epoch 137/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9858 - loss: 0.7727 - val_accuracy: 0.8820 - val_loss: 1.0785
# Epoch 138/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9782 - loss: 0.7714 - val_accuracy: 0.8984 - val_loss: 1.0558
# Epoch 139/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9831 - loss: 0.7430 - val_accuracy: 0.8934 - val_loss: 1.0459
# Epoch 140/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9866 - loss: 0.7203 - val_accuracy: 0.8885 - val_loss: 1.0354
# Epoch 141/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9811 - loss: 0.7185 - val_accuracy: 0.8918 - val_loss: 1.0162
# Epoch 142/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9829 - loss: 0.6917 - val_accuracy: 0.9049 - val_loss: 0.9924
# Epoch 143/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9873 - loss: 0.6736 - val_accuracy: 0.8951 - val_loss: 0.9824
# Epoch 144/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9918 - loss: 0.6576 - val_accuracy: 0.9000 - val_loss: 0.9614
# Epoch 145/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9882 - loss: 0.6388 - val_accuracy: 0.8902 - val_loss: 0.9533
# Epoch 146/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9883 - loss: 0.6270 - val_accuracy: 0.8934 - val_loss: 0.9423
# Epoch 147/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9914 - loss: 0.6092 - val_accuracy: 0.8820 - val_loss: 0.9326
# Epoch 148/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9826 - loss: 0.6124 - val_accuracy: 0.8852 - val_loss: 0.9351
# Epoch 149/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9687 - loss: 0.6397 - val_accuracy: 0.8754 - val_loss: 0.9994
# Epoch 150/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9601 - loss: 0.6361 - val_accuracy: 0.8738 - val_loss: 0.9236
# Epoch 151/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9715 - loss: 0.6088 - val_accuracy: 0.8787 - val_loss: 0.9172
# Epoch 152/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9818 - loss: 0.5822 - val_accuracy: 0.8934 - val_loss: 0.8847
# Epoch 153/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9820 - loss: 0.5604 - val_accuracy: 0.8869 - val_loss: 0.8784
# Epoch 154/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9884 - loss: 0.5380 - val_accuracy: 0.8836 - val_loss: 0.8623
# Epoch 155/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9830 - loss: 0.5355 - val_accuracy: 0.8869 - val_loss: 0.8468
# Epoch 156/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9917 - loss: 0.5098 - val_accuracy: 0.8852 - val_loss: 0.8370
# Epoch 157/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9889 - loss: 0.5127 - val_accuracy: 0.8934 - val_loss: 0.8386
# Epoch 158/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.4917 - val_accuracy: 0.8885 - val_loss: 0.8261
# Epoch 159/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9862 - loss: 0.4825 - val_accuracy: 0.8918 - val_loss: 0.8165
# Epoch 160/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9907 - loss: 0
500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9965 - loss: 0.1868 - val_accuracy: 0.8836 - val_loss: 0.5332
# Epoch 236/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9887 - loss: 0.1897 - val_accuracy: 0.8902 - val_loss: 0.5327
# Epoch 237/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9943 - loss: 0.1910 - val_accuracy: 0.8934 - val_loss: 0.5339
# Epoch 238/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9918 - loss: 0.1963 - val_accuracy: 0.9033 - val_loss: 0.5313
# Epoch 239/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9939 - loss: 0.1916 - val_accuracy: 0.8918 - val_loss: 0.5392
# Epoch 240/500
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9922 - loss: 0.1940 - val_accuracy: 0.8836 - val_loss: 0.5425
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Training Accuracy: 0.9777
# Testing Accuracy: 0.8898
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#          0.0     0.9062    0.9134    0.9098       381
#          1.0     0.8382    0.8860    0.8615       193
#          2.0     0.9138    0.8457    0.8785       188
#
#     accuracy                         0.8898       762
#    macro avg     0.8861    0.8817    0.8832       762
# weighted avg     0.8909    0.8898    0.8898       762

# %% [markdown]
# CV for transformer model

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Dense, Dropout, LayerNormalization, GlobalAveragePooling1D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/eeg-motor-v1/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Reshape X to fit Transformer expected input (samples, timesteps, features)
X = np.expand_dims(X, axis=1)  # Now shape: (num_samples, 1, num_features)

# Get number of unique classes
num_classes = len(np.unique(y))

# Number of folds for cross-validation
K = 10  

# Initialize Stratified K-Fold
skf = StratifiedKFold(n_splits=K, shuffle=True, random_state=42)

# Store performance metrics
train_accuracies = []
test_accuracies = []
history_list = []  
conf_matrices = []  

# ------------------------
# Positional Encoding Function
# ------------------------
def positional_encoding(length, depth):
    """
    Generate positional encoding for input sequences.
    """
    pos = np.arange(length)[:, np.newaxis]
    i = np.arange(depth)[np.newaxis, :]
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(depth))
    angle_rads = pos * angle_rates

    # Apply sin to even indices, cos to odd indices
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    return tf.convert_to_tensor(angle_rads, dtype=tf.float32)

# ------------------------
# Transformer Block
# ------------------------
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.6):
        super(TransformerBlock, self).__init__()
        self.att = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation="relu", kernel_regularizer=l2(0.05)),
            Dense(embed_dim, kernel_regularizer=l2(0.05))
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training=False):
        attn_output = self.att(inputs, inputs, training=training)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1, training=training)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# ------------------------
# Transformer Model
# ------------------------
def build_transformer(input_shape, num_classes, embed_dim=32, num_heads=2, ff_dim=64, num_blocks=2, dropout_rate=0.6):
    inputs = Input(shape=input_shape)

    # Positional Encoding
    positions = positional_encoding(input_shape[0], embed_dim)
    x = Dense(embed_dim, kernel_regularizer=l2(0.05))(inputs)  
    x += positions  

    # Transformer Blocks
    for _ in range(num_blocks):
        x = TransformerBlock(embed_dim, num_heads, ff_dim, dropout_rate)(x)

    # Classification Head
    x = GlobalAveragePooling1D()(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(num_classes, activation="softmax", kernel_regularizer=l2(0.05))(x)

    return Model(inputs, outputs)

# ------------------------
# Cross-Validation Training & Evaluation
# ------------------------
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    print(f"\nTraining on Fold {fold + 1}/{K}...\n")
    
    # Get train-test split for current fold
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # Build a new model for each fold
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_transformer(input_shape, num_classes)

    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])

    # Early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Train the model
    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=500,
        batch_size=128,
        callbacks=[early_stopping],
        verbose=0
    )

    # Store history
    history_list.append(history.history)

    # Evaluate model
    y_train_pred = np.argmax(model.predict(X_train), axis=1)
    y_test_pred = np.argmax(model.predict(X_test), axis=1)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)

    print(f"Fold {fold + 1} - Training Accuracy: {train_accuracy:.4f}")
    print(f"Fold {fold + 1} - Testing Accuracy: {test_accuracy:.4f}")

    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)

    # Store Confusion Matrix
    conf_matrices.append(confusion_matrix(y_test, y_test_pred))

# ------------------------
# Compute Overall Performance
# ------------------------
mean_train_accuracy = np.mean(train_accuracies)
std_train_accuracy = np.std(train_accuracies)

mean_test_accuracy = np.mean(test_accuracies)
std_test_accuracy = np.std(test_accuracies)

print("\n----------------------")
print(f"Mean Training Accuracy: {mean_train_accuracy:.4f} ± {std_train_accuracy:.4f}")
print(f"Mean Testing Accuracy: {mean_test_accuracy:.4f} ± {std_test_accuracy:.4f}")
print("----------------------")

# ------------------------
# Plot Mean Confusion Matrix
# ------------------------
mean_conf_matrix = np.mean(conf_matrices, axis=0)

plt.figure(figsize=(6,5))
sns.heatmap(mean_conf_matrix, annot=True, fmt='.1f', cmap="Blues",
            xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Mean Confusion Matrix across Folds")
plt.show()
# Out:
# Training on Fold 1/10...
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step
# Fold 1 - Training Accuracy: 0.9743
# Fold 1 - Testing Accuracy: 0.8924
#
# Training on Fold 2/10...
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# Fold 2 - Training Accuracy: 0.9734
# Fold 2 - Testing Accuracy: 0.8976
#
# Training on Fold 3/10...
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# Fold 3 - Training Accuracy: 0.9734
# Fold 3 - Testing Accuracy: 0.8950
#
# Training on Fold 4/10...
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# Fold 4 - Training Accuracy: 0.9734
# Fold 4 - Testing Accuracy: 0.8583
#
# Training on Fold 5/10...
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# Fold 5 - Training Accuracy: 0.9743
# Fold 5 - Testing Accuracy: 0.8819
#
# Training on Fold 6/10...
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# Fold 6 - Training Accuracy: 0.9729
# Fold 6 - Testing Accuracy: 0.8845
#
# Training on Fold 7/10...
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# Fold 7 - Training Accuracy: 0.9732
# Fold 7 - Testing Accuracy: 0.8845
#
# Training on Fold 8/10...
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# Fold 8 - Training Accuracy: 0.9737
# Fold 8 - Testing Accuracy: 0.8845
#
# Training on Fold 9/10...
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step
# Fold 9 - Training Accuracy: 0.9714
# Fold 9 - Testing Accuracy: 0.8842
#
# Training on Fold 10/10...
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (32, 2, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# Fold 10 - Training Accuracy: 0.9700
# Fold 10 - Testing Accuracy: 0.8947
#
# ----------------------
# Mean Training Accuracy: 0.9730 ± 0.0013
# Mean Testing Accuracy: 0.8858 ± 0.0106
# ----------------------

# %% [markdown]
# EEGNet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Dense, Dropout, Flatten, Conv2D, DepthwiseConv2D, SeparableConv2D,
                                     BatchNormalization, Activation, AveragePooling2D, Lambda)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Reshape data to match EEGNet input: (Samples, Channels, Time_Points, 1)
# Assuming EEG data is structured in a way where first dimension represents channels
channels = 19  # Adjust based on actual data
time_points = X.shape[1] // channels  # Infer time points from total features
X = X.reshape(-1, channels, time_points, 1)

# Train-Test Split with Stratification
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, shuffle=True, random_state=42
)

# Convert labels to categorical
num_classes = len(np.unique(y))
y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

# ------------------------
# Define EEGNet Model
# ------------------------
def EEGNet(nb_classes, Chans=19, Samples=200, dropoutRate=0.1, kernLength=64, F1=8, D=2, F2=16):
    input1 = Input(shape=(Chans, Samples, 1))

    # First convolutional block
    block1 = Conv2D(F1, (1, kernLength), padding='same', use_bias=False)(input1)
    block1 = BatchNormalization()(block1)
    block1 = DepthwiseConv2D((Chans, 1), use_bias=False, depth_multiplier=D,
                              depthwise_constraint=tf.keras.constraints.MaxNorm(1.))(block1)
    block1 = BatchNormalization()(block1)
    block1 = Activation('elu')(block1)
    block1 = AveragePooling2D((1, 4))(block1)
    block1 = Dropout(dropoutRate)(block1)

    # Second convolutional block
    block2 = SeparableConv2D(F2, (1, 16), use_bias=False, padding='same')(block1)
    block2 = BatchNormalization()(block2)
    block2 = Activation('elu')(block2)
    block2 = AveragePooling2D((1, 8))(block2)
    block2 = Dropout(dropoutRate)(block2)

    # Classification block
    flatten = Flatten(name='flatten')(block2)
    dense = Dense(nb_classes, name='dense', kernel_constraint=tf.keras.constraints.MaxNorm(0.25))(flatten)
    softmax = Activation('softmax', name='softmax')(dense)

    return Model(inputs=input1, outputs=softmax)

# ------------------------
# Build and Compile EEGNet Model
# ------------------------
model = EEGNet(nb_classes=num_classes, Chans=channels, Samples=time_points)
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# ------------------------
# Train the Model
# ------------------------
history = model.fit(X_train, y_train,
                    validation_split=0.2,
                    epochs=250,
                    batch_size=128,
                    callbacks=[early_stopping],
                    verbose=1)

# ------------------------
# Evaluate the Model
# ------------------------
y_train_pred = np.argmax(model.predict(X_train), axis=1)
y_test_pred = np.argmax(model.predict(X_test), axis=1)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"📌 Training Accuracy: {train_accuracy:.4f}")
print(f"📌 Testing Accuracy: {test_accuracy:.4f}")

from sklearn.metrics import classification_report

# Print classification report for the test set
print("\nClassification Report (Test Set):")
print(classification_report(y_test, y_test_pred, digits=4))


# ------------------------
# Plot Confusion Matrix
# ------------------------
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(6,5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap="Blues",
            xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# ------------------------
# Plot Training History
# ------------------------
plt.figure(figsize=(12,5))

# Plot Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.3830 - loss: 1.1243 - val_accuracy: 0.4508 - val_loss: 1.0964
# Epoch 2/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4188 - loss: 1.0831 - val_accuracy: 0.4918 - val_loss: 1.0945
# Epoch 3/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4661 - loss: 1.0740 - val_accuracy: 0.5033 - val_loss: 1.0922
# Epoch 4/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4756 - loss: 1.0685 - val_accuracy: 0.5066 - val_loss: 1.0898
# Epoch 5/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4838 - loss: 1.0630 - val_accuracy: 0.5033 - val_loss: 1.0870
# Epoch 6/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5080 - loss: 1.0572 - val_accuracy: 0.5131 - val_loss: 1.0837
# Epoch 7/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5358 - loss: 1.0473 - val_accuracy: 0.5197 - val_loss: 1.0797
# Epoch 8/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5097 - loss: 1.0438 - val_accuracy: 0.5279 - val_loss: 1.0749
# Epoch 9/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5349 - loss: 1.0340 - val_accuracy: 0.5361 - val_loss: 1.0689
# Epoch 10/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5309 - loss: 1.0321 - val_accuracy: 0.5541 - val_loss: 1.0619
# Epoch 11/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5411 - loss: 1.0195 - val_accuracy: 0.5508 - val_loss: 1.0548
# Epoch 12/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5393 - loss: 1.0089 - val_accuracy: 0.5574 - val_loss: 1.0465
# Epoch 13/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5554 - loss: 1.0058 - val_accuracy: 0.5574 - val_loss: 1.0374
# Epoch 14/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5572 - loss: 0.9966 - val_accuracy: 0.5574 - val_loss: 1.0277
# Epoch 15/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5541 - loss: 0.9960 - val_accuracy: 0.5607 - val_loss: 1.0182
# Epoch 16/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5602 - loss: 0.9881 - val_accuracy: 0.5607 - val_loss: 1.0100
# Epoch 17/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5553 - loss: 0.9878 - val_accuracy: 0.5623 - val_loss: 1.0012
# Epoch 18/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5808 - loss: 0.9710 - val_accuracy: 0.5525 - val_loss: 0.9924
# Epoch 19/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5691 - loss: 0.9655 - val_accuracy: 0.5508 - val_loss: 0.9844
# Epoch 20/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5751 - loss: 0.9704 - val_accuracy: 0.5525 - val_loss: 0.9786
# Epoch 21/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5576 - loss: 0.9671 - val_accuracy: 0.5590 - val_loss: 0.9733
# Epoch 22/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5653 - loss: 0.9701 - val_accuracy: 0.5574 - val_loss: 0.9683
# Epoch 23/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5715 - loss: 0.9563 - val_accuracy: 0.5557 - val_loss: 0.9639
# Epoch 24/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5597 - loss: 0.9690 - val_accuracy: 0.5574 - val_loss: 0.9602
# Epoch 25/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5852 - loss: 0.9422 - val_accuracy: 0.5590 - val_loss: 0.9558
# Epoch 26/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5786 - loss: 0.9394 - val_accuracy: 0.5541 - val_loss: 0.9530
# Epoch 27/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5778 - loss: 0.9470 - val_accuracy: 0.5557 - val_loss: 0.9502
# Epoch 28/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.
250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6519 - loss: 0.7634 - val_accuracy: 0.6705 - val_loss: 0.7505
# Epoch 188/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6882 - loss: 0.7354 - val_accuracy: 0.6689 - val_loss: 0.7528
# Epoch 189/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6898 - loss: 0.7247 - val_accuracy: 0.6639 - val_loss: 0.7544
# Epoch 190/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6802 - loss: 0.7380 - val_accuracy: 0.6607 - val_loss: 0.7547
# Epoch 191/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6797 - loss: 0.7396 - val_accuracy: 0.6639 - val_loss: 0.7554
# Epoch 192/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6885 - loss: 0.7291 - val_accuracy: 0.6607 - val_loss: 0.7522
# Epoch 193/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7030 - loss: 0.7297 - val_accuracy: 0.6623 - val_loss: 0.7516
# Epoch 194/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7016 - loss: 0.7239 - val_accuracy: 0.6672 - val_loss: 0.7511
# Epoch 195/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6675 - loss: 0.7468 - val_accuracy: 0.6639 - val_loss: 0.7526
# Epoch 196/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6907 - loss: 0.7368 - val_accuracy: 0.6639 - val_loss: 0.7549
# Epoch 197/250
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6899 - loss: 0.7384 - val_accuracy: 0.6672 - val_loss: 0.7528
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 📌 Training Accuracy: 0.6825
# 📌 Testing Accuracy: 0.6457
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#          0.0     0.7345    0.8714    0.7971       381
#          1.0     0.5371    0.4870    0.5109       193
#          2.0     0.4889    0.3511    0.4087       188
#
#     accuracy                         0.6457       762
#    macro avg     0.5868    0.5698    0.5722       762
# weighted avg     0.6239    0.6457    0.6288       762

# %% [markdown]
# cv for EEGNeT

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Dense, Dropout, Flatten, Conv2D, DepthwiseConv2D, SeparableConv2D,
                                     BatchNormalization, Activation, AveragePooling2D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/eeg-motor-v1/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Reshape data to match EEGNet input: (Samples, Channels, Time_Points, 1)
channels = 19  # Adjust based on actual data
time_points = X.shape[1] // channels  # Infer time points from total features
X = X.reshape(-1, channels, time_points, 1)

# Get number of unique classes
num_classes = len(np.unique(y))

# Number of folds for cross-validation
K = 10  

# Initialize Stratified K-Fold
skf = StratifiedKFold(n_splits=K, shuffle=True, random_state=42)

# Store performance metrics
train_accuracies = []
test_accuracies = []
history_list = []  
conf_matrices = []  

# ------------------------
# Define EEGNet Model
# ------------------------
def EEGNet(nb_classes, Chans=19, Samples=200, dropoutRate=0.1, kernLength=64, F1=8, D=2, F2=16):
    input1 = Input(shape=(Chans, Samples, 1))

    # First convolutional block
    block1 = Conv2D(F1, (1, kernLength), padding='same', use_bias=False)(input1)
    block1 = BatchNormalization()(block1)
    block1 = DepthwiseConv2D((Chans, 1), use_bias=False, depth_multiplier=D,
                              depthwise_constraint=tf.keras.constraints.MaxNorm(1.))(block1)
    block1 = BatchNormalization()(block1)
    block1 = Activation('elu')(block1)
    block1 = AveragePooling2D((1, 4))(block1)
    block1 = Dropout(dropoutRate)(block1)

    # Second convolutional block
    block2 = SeparableConv2D(F2, (1, 16), use_bias=False, padding='same')(block1)
    block2 = BatchNormalization()(block2)
    block2 = Activation('elu')(block2)
    block2 = AveragePooling2D((1, 8))(block2)
    block2 = Dropout(dropoutRate)(block2)

    # Classification block
    flatten = Flatten(name='flatten')(block2)
    dense = Dense(nb_classes, name='dense', kernel_constraint=tf.keras.constraints.MaxNorm(0.25))(flatten)
    softmax = Activation('softmax', name='softmax')(dense)

    return Model(inputs=input1, outputs=softmax)

# ------------------------
# Cross-Validation Training & Evaluation
# ------------------------
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    print(f"\n🔄 Training on Fold {fold + 1}/{K}...\n")
    
    # Get train-test split for current fold
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # Build a new model for each fold
    model = EEGNet(nb_classes=num_classes, Chans=channels, Samples=time_points)

    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])

    # Early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Train the model
    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=250,
        batch_size=128,
        callbacks=[early_stopping],
        verbose=0  # Suppress training output
    )

    # Store history
    history_list.append(history.history)

    # Evaluate model
    y_train_pred = np.argmax(model.predict(X_train), axis=1)
    y_test_pred = np.argmax(model.predict(X_test), axis=1)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)

    print(f"✅ Fold {fold + 1} - Training Accuracy: {train_accuracy:.4f}")
    print(f"✅ Fold {fold + 1} - Testing Accuracy: {test_accuracy:.4f}")

    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)

    # Store Confusion Matrix
    conf_matrices.append(confusion_matrix(y_test, y_test_pred))

# ------------------------
# Compute Overall Performance
# ------------------------
mean_train_accuracy = np.mean(train_accuracies)
std_train_accuracy = np.std(train_accuracies)

mean_test_accuracy = np.mean(test_accuracies)
std_test_accuracy = np.std(test_accuracies)

print("\n📊 ----------------------")
print(f"📌 Mean Training Accuracy: {mean_train_accuracy:.4f} ± {std_train_accuracy:.4f}")
print(f"📌 Mean Testing Accuracy: {mean_test_accuracy:.4f} ± {std_test_accuracy:.4f}")
print("----------------------")

# ------------------------
# Plot Mean Confusion Matrix
# ------------------------
mean_conf_matrix = np.mean(conf_matrices, axis=0)

plt.figure(figsize=(6,5))
sns.heatmap(mean_conf_matrix, annot=True, fmt='.1f', cmap="Blues",
            xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Mean Confusion Matrix across Folds")
plt.show()
# Out:
# 🔄 Training on Fold 1/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ✅ Fold 1 - Training Accuracy: 0.7333
# ✅ Fold 1 - Testing Accuracy: 0.7192
#
# 🔄 Training on Fold 2/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ✅ Fold 2 - Training Accuracy: 0.6898
# ✅ Fold 2 - Testing Accuracy: 0.6745
#
# 🔄 Training on Fold 3/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ✅ Fold 3 - Training Accuracy: 0.7123
# ✅ Fold 3 - Testing Accuracy: 0.6719
#
# 🔄 Training on Fold 4/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ✅ Fold 4 - Training Accuracy: 0.7207
# ✅ Fold 4 - Testing Accuracy: 0.6798
#
# 🔄 Training on Fold 5/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ✅ Fold 5 - Training Accuracy: 0.7423
# ✅ Fold 5 - Testing Accuracy: 0.6772
#
# 🔄 Training on Fold 6/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ✅ Fold 6 - Training Accuracy: 0.7242
# ✅ Fold 6 - Testing Accuracy: 0.7323
#
# 🔄 Training on Fold 7/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# ✅ Fold 7 - Training Accuracy: 0.7114
# ✅ Fold 7 - Testing Accuracy: 0.7034
#
# 🔄 Training on Fold 8/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ✅ Fold 8 - Training Accuracy: 0.7117
# ✅ Fold 8 - Testing Accuracy: 0.6929
#
# 🔄 Training on Fold 9/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ✅ Fold 9 - Training Accuracy: 0.7567
# ✅ Fold 9 - Testing Accuracy: 0.6921
#
# 🔄 Training on Fold 10/10...
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# ✅ Fold 10 - Training Accuracy: 0.7275
# ✅ Fold 10 - Testing Accuracy: 0.7421
#
# 📊 ----------------------
# 📌 Mean Training Accuracy: 0.7230 ± 0.0177
# 📌 Mean Testing Accuracy: 0.6985 ± 0.0238
# ----------------------

# %% [markdown]
# XGBoost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Train-Test Split with Stratification
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, shuffle=True, random_state=42
)

# ------------------------
# XGBoost Model Configuration
# ------------------------
xgb_model = xgb.XGBClassifier(
    objective="multi:softmax",  # Multi-class classification
    num_class=len(np.unique(y)),  # Number of classes
    # max_depth=6,  # Maximum depth of trees
    learning_rate=0.01,  # Learning rate
    n_estimators=300,  # Number of boosting rounds
    subsample=0.8,  # Fraction of training samples
    colsample_bytree=0.8,  # Feature sampling
    random_state=42
)

# ------------------------
# Train the Model
# ------------------------
xgb_model.fit(X_train, y_train)

# ------------------------
# Evaluate the Model
# ------------------------
y_train_pred = xgb_model.predict(X_train)
y_test_pred = xgb_model.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Testing Accuracy: {test_accuracy:.4f}")

from sklearn.metrics import classification_report

# Print classification report for the test set
print("\nClassification Report (Test Set):")
print(classification_report(y_test, y_test_pred, digits=4))

# ------------------------
# Plot Confusion Matrix
# ------------------------
conf_matrix = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(6,5), dpi=300)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap="Blues",
            xticklabels=range(len(np.unique(y))), 
            yticklabels=range(len(np.unique(y))))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# ------------------------
# Plot Feature Importance
# ------------------------
plt.figure(figsize=(10, 5), dpi=300)
xgb.plot_importance(xgb_model, importance_type="weight", max_num_features=15)
plt.title("Top 15 Feature Importances - XGBoost")
plt.show()
# Out:
# Training Accuracy: 0.9905
# Testing Accuracy: 0.8635
#
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#          0.0     0.8426    0.9554    0.8954       381
#          1.0     0.8902    0.7979    0.8415       193
#          2.0     0.8917    0.7447    0.8116       188
#
#     accuracy                         0.8635       762
#    macro avg     0.8748    0.8327    0.8495       762
# weighted avg     0.8668    0.8635    0.8611       762

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix

# ------------------------
# Load and Preprocess Data
# ------------------------
dataset_path = "/kaggle/input/eeg-motor-v1/combined_eeg_features.csv"
df = pd.read_csv(dataset_path, header=None)

# Separate features and labels
X = df.iloc[:, :-1].values  # Features
y = df.iloc[:, -1].values   # Labels

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# ------------------------
# XGBoost Model Configuration
# ------------------------
xgb_params = {
    "objective": "multi:softmax",  # Multi-class classification
    "num_class": len(np.unique(y)),  # Number of classes
    "max_depth": 6,  # Tree depth
    "learning_rate": 0.01,  # Learning rate
    "n_estimators": 300,  # Boosting rounds
    "subsample": 0.8,  # Fraction of training samples per tree
    "colsample_bytree": 0.8,  # Feature sampling
    "random_state": 42
}

# ------------------------
# 10-Fold Stratified Cross-Validation
# ------------------------
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
fold_accuracies = []

for fold, (train_idx, test_idx) in enumerate(kf.split(X, y)):
    print(f"Training Fold {fold+1}/10...")
    
    # Split data
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # Train XGBoost model
    model = xgb.XGBClassifier(**xgb_params)
    model.fit(X_train, y_train)

    # Evaluate Model
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    fold_accuracies.append(accuracy)
    
    print(f"Fold {fold+1} Accuracy: {accuracy:.4f}")

# ------------------------
# Overall Performance
# ------------------------
mean_accuracy = np.mean(fold_accuracies)
std_accuracy = np.std(fold_accuracies)

print(f"\nMean Accuracy: {mean_accuracy:.4f}")
print(f"Standard Deviation: {std_accuracy:.4f}")

# ------------------------
# Plot Confusion Matrix (Last Fold)
# ------------------------
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5), dpi=300)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap="Blues",
            xticklabels=range(len(np.unique(y))), 
            yticklabels=range(len(np.unique(y))))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(f"Confusion Matrix - Fold {fold+1}")
plt.show()
# Out:
# Training Fold 1/10...
# Fold 1 Accuracy: 0.8556
# Training Fold 2/10...
# Fold 2 Accuracy: 0.8609
# Training Fold 3/10...
# Fold 3 Accuracy: 0.8635
# Training Fold 4/10...
# Fold 4 Accuracy: 0.8294
# Training Fold 5/10...
# Fold 5 Accuracy: 0.8425
# Training Fold 6/10...
# Fold 6 Accuracy: 0.8556
# Training Fold 7/10...
# Fold 7 Accuracy: 0.8845
# Training Fold 8/10...
# Fold 8 Accuracy: 0.8241
# Training Fold 9/10...
# Fold 9 Accuracy: 0.8316
# Training Fold 10/10...
# Fold 10 Accuracy: 0.8526
#
# Mean Accuracy: 0.8500
# Standard Deviation: 0.0175
